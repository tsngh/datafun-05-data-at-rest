# %% [markdown]
# # Extra Credit

# %% [markdown]
# By: [Tesheena](https://github.com/tsngh/)

# %% [markdown]
# 09/24/2023

# %% [markdown]
# ##Use pandas to import the csv dataset into a DataFrame

# %%
import pandas as pd

df= pd.read_csv('Table 3-1.csv')

df
# Out:
#     Table 3-1:  CO2, CH4, and N2O Emissions from Energy (MMT CO2 Eq.)  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# ...

# %% [markdown]
# ##Use the DataFrame commands to clean the data as needed and/or rename the columns.

# %%
newdf = df.drop([0,1]) ##dropping first and second row

# %%
newdf.columns= ['Table','Source','Year1990', 'Year1991', 'Year1992', 'Year1993', 'Year1994','Year1995', 'Year1996', 'Year1997',
                 'Year1998','Year1999', 'Year2000','Year2001', 'Year2002', 'Year2003', 'Year2004','Year2005','Year2006','Year2007','Year2008',
                 'Year2009','Year2010','Year2011','Year2012', 'Year2013', 'Year2014']  ##renaming columns
new_df= newdf.drop(columns=['Table']) ##removing columns
newer_df =new_df.drop(columns=['Year1990', 'Year1991','Year1992','Year1993','Year1994','Year1995','Year1996','Year1997','Year1998','Year1999'])

# %% [markdown]
# ##Use the DataFrame describe() function to calculate basic descriptive statistics.

# %%
newer_df.head()
# Out:
#                       Source Year2000 Year2001 Year2002 Year2003 Year2004  \
# 2                        CO2   5779.2   5702.4   5743.3     5795     5902
# 3     Fossil Fuel Combustion     5594   5525.2   5560.9     5620   5709.2
# 4     Electricity Generation   2296.9   2257.9   2272.7   2304.2   2335.9
# 5             Transportation   1805.5   1789.4   1830.6   1822.3   1867.1
# 6                 Industrial    854.1      843    829.8    829.6    852.3
#
#   Year2005 Year2006 Year2007 Year2008 Year2009 Year2010 Year2011 Year2012  \
# 2   5932.5   5847.3     5924   5740.5   5347.1     5520   5386.6   5179.7
# 3   5747.1   5660.6   5751.2   5566.7   5193.5   5358.3   5227.7   5024.7
# 4   2400.9   2345.3   2411.9   2360.1   2145.7   2258.4   2157.7   2022.2
# 5     1887   1882.6   1886.1   1791.8     1717   1728.3   1707.6   1696.8
# 6      828    852.6    847.9    802.8    727.7    775.5    773.3    782.9
#
#   Year2013 Year2014
# 2   5330.8   5377.9
# 3   5157.6   5208.2
# ...

# %%
newer_df = pd.DataFrame({ 'object': ['a', 'b', 'c'],
                     'numeric': [1, 2, 3],
                     'categorical': pd.Categorical(['d','e','f'])
                  })

newer_df.describe(include='all')  ##had issues with std, min, max and percentiles not showing
# Out:
#        object  numeric categorical
# count       3      3.0           3
# unique      3      NaN           3
# top         a      NaN           d
# freq        1      NaN           1
# mean      NaN      2.0         NaN
# std       NaN      1.0         NaN
# min       NaN      1.0         NaN
# 25%       NaN      1.5         NaN
# 50%       NaN      2.0         NaN
# 75%       NaN      2.5         NaN
# max       NaN      3.0         NaN

# %% [markdown]
# ##Use the DataFrame hist() function to generate histograms for all numeric columns.

# %%
# %matplotlib inline

# %%
histogram =newer_df.hist()
